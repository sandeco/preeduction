# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

si = pd.read_csv('si.csv')

si.describe()
# Out:
#        SIT_MATRICULA  PAI_FALECIDO  MAE_FALECIDO  RENDA_FAMILIAR  \
# count    1320.000000   1234.000000        1266.0     1136.000000
# mean        1.141667      0.024311           0.0        0.795775
# std         2.957432      0.154076           0.0        1.585346
# min         0.000000      0.000000           0.0        0.000000
# 25%         0.000000      0.000000           0.0        0.000000
# 50%         0.000000      0.000000           0.0        0.000000
# 75%         0.000000      0.000000           0.0        0.000000
# max        10.000000      1.000000           0.0        6.000000
#
#        ANO_CONCLUSAO_2_GRAU  RENDA_PER_CAPITA    N_FILHOS  NIVEL_FALA  \
# count           1270.000000       1196.000000  841.000000  357.000000
# mean            2010.248819          8.959030    0.026159    1.358543
# std                4.678082          2.778427    0.159704    0.595174
# min             1982.000000          0.000000    0.000000    1.000000
# 25%             2009.000000         10.000000    0.000000    1.000000
# 50%             2012.000000         10.000000    0.000000    1.000000
# 75%             2013.000000         10.000000    0.000000    2.000000
# max             2014.000000         10.000000    1.000000    3.000000
#
#        NIVEL_COMPREENSAO  NIVEL_ESCRITA  NIVEL_LEITURA     N_FALTAS  \
# count         357.000000     357.000000     357.000000  1199.000000
# mean            1.848739       1.694678       2.028011     8.797331
# std             0.502331       0.626476       0.575042    14.881775
# min             1.000000       1.000000       1.000000     0.000000
# 25%             2.000000       1.000000       2.000000     0.000000
# 50%             2.000000       2.000000       2.000000     4.000000
# 75%             2.000000       2.000000       2.000000     8.000000
# max             3.000000       3.000000       3.000000   108.000000
#
#        COD_DISCIPLINA    CARGA_HOR  ANO_INGRESSO
# count     1320.000000  1320.000000   1320.000000
# mean     19158.448485    50.993182   2013.856818
# std       4587.214008    13.018123      0.867201
# min       8028.000000    27.000000   2013.000000
# 25%      19403.000000    54.000000   2013.000000
# 50%      20179.000000    54.000000   2014.000000
# 75%      22581.000000    54.000000   2014.000000
# max      24711.000000    81.000000   2016.000000

# %%
si.dtypes
# Out:
# SIT_MATRICULA             int64
# PAI_FALECIDO            float64
# MAE_FALECIDO            float64
# RENDA_FAMILIAR          float64
# TIPO_ESCOLA_ORIGEM       object
# ANO_CONCLUSAO_2_GRAU    float64
# RENDA_PER_CAPITA        float64
# COD_ESTADO_CIVIL         object
# N_FILHOS                float64
# SEXO                     object
# DT_NASCIMENTO            object
# PROFISSAO                object
# DESC_CIDADE              object
# DESC_ESTADO              object
# DESC_IDIOMA              object
# NIVEL_FALA              float64
# NIVEL_COMPREENSAO       float64
# NIVEL_ESCRITA           float64
# NIVEL_LEITURA           float64
# NOTAS                    object
# N_FALTAS                float64
# COD_DISCIPLINA            int64
# CARGA_HOR                 int64
# ANO_INGRESSO              int64
# dtype: object

# %%
si.describe()
# Out:
#        SIT_MATRICULA  PAI_FALECIDO  MAE_FALECIDO  RENDA_FAMILIAR  \
# count    1320.000000   1234.000000        1266.0     1136.000000
# mean        1.141667      0.024311           0.0        0.795775
# std         2.957432      0.154076           0.0        1.585346
# min         0.000000      0.000000           0.0        0.000000
# 25%         0.000000      0.000000           0.0        0.000000
# 50%         0.000000      0.000000           0.0        0.000000
# 75%         0.000000      0.000000           0.0        0.000000
# max        10.000000      1.000000           0.0        6.000000
#
#        ANO_CONCLUSAO_2_GRAU  RENDA_PER_CAPITA    N_FILHOS  NIVEL_FALA  \
# count           1270.000000       1196.000000  841.000000  357.000000
# mean            2010.248819          8.959030    0.026159    1.358543
# std                4.678082          2.778427    0.159704    0.595174
# min             1982.000000          0.000000    0.000000    1.000000
# 25%             2009.000000         10.000000    0.000000    1.000000
# 50%             2012.000000         10.000000    0.000000    1.000000
# 75%             2013.000000         10.000000    0.000000    2.000000
# max             2014.000000         10.000000    1.000000    3.000000
#
#        NIVEL_COMPREENSAO  NIVEL_ESCRITA  NIVEL_LEITURA     N_FALTAS  \
# count         357.000000     357.000000     357.000000  1199.000000
# mean            1.848739       1.694678       2.028011     8.797331
# std             0.502331       0.626476       0.575042    14.881775
# min             1.000000       1.000000       1.000000     0.000000
# 25%             2.000000       1.000000       2.000000     0.000000
# 50%             2.000000       2.000000       2.000000     4.000000
# 75%             2.000000       2.000000       2.000000     8.000000
# max             3.000000       3.000000       3.000000   108.000000
#
#        COD_DISCIPLINA    CARGA_HOR  ANO_INGRESSO
# count     1320.000000  1320.000000   1320.000000
# mean     19158.448485    50.993182   2013.856818
# std       4587.214008    13.018123      0.867201
# min       8028.000000    27.000000   2013.000000
# 25%      19403.000000    54.000000   2013.000000
# 50%      20179.000000    54.000000   2014.000000
# 75%      22581.000000    54.000000   2014.000000
# max      24711.000000    81.000000   2016.000000

# %%
#EXCLUINDO AS COLUNAS [PAI_FALECIDO, MAE_FALECIDO]
si.drop('PAI_FALECIDO',axis=1, inplace=True)
si.drop('MAE_FALECIDO',axis=1, inplace=True)

si.dtypes
# Out:
# SIT_MATRICULA             int64
# RENDA_FAMILIAR          float64
# TIPO_ESCOLA_ORIGEM       object
# ANO_CONCLUSAO_2_GRAU    float64
# RENDA_PER_CAPITA        float64
# COD_ESTADO_CIVIL         object
# N_FILHOS                float64
# SEXO                     object
# DT_NASCIMENTO            object
# PROFISSAO                object
# DESC_CIDADE              object
# DESC_ESTADO              object
# DESC_IDIOMA              object
# NIVEL_FALA              float64
# NIVEL_COMPREENSAO       float64
# NIVEL_ESCRITA           float64
# NIVEL_LEITURA           float64
# NOTAS                    object
# N_FALTAS                float64
# COD_DISCIPLINA            int64
# CARGA_HOR                 int64
# ANO_INGRESSO              int64
# dtype: object

# %%
# Usando somentes as tuplas em que o idioma é inglês ou NULL

si = si.loc[(si['DESC_IDIOMA']=='Inglês') | (si['DESC_IDIOMA'].isnull())]

#si

# %%
#RENOMEANDO CAMPOS DAS 4 HABILIDADES EM INGLÊS
si = si.rename(columns = {'NIVEL_FALA':'INGLES_FALA'})
si = si.rename(columns = {'NIVEL_COMPREENSAO':'INGLES_COMPREENSAO'})
si = si.rename(columns = {'NIVEL_ESCRITA':'INGLES_ESCRITA'})
si = si.rename(columns = {'NIVEL_LEITURA':'INGLES_LEITURA'})

#EXCLUINDO O ATRIBUTO DESC_IDIOMA
si.drop('DESC_IDIOMA',axis=1, inplace=True)

si
# Out:
#       SIT_MATRICULA  RENDA_FAMILIAR TIPO_ESCOLA_ORIGEM  ANO_CONCLUSAO_2_GRAU  \
# 0                 9             NaN                  E                2012.0
# 1                 0             2.0                  E                2009.0
# 2                 0             0.0                  E                2007.0
# 3                 0             0.0                  E                2011.0
# 4                 0             4.0                  P                2012.0
# 6                 0             NaN                  E                2013.0
# 7                 0             NaN                  E                2007.0
# 8                 0             0.0                  P                2012.0
# 9                 9             0.0                  E                2007.0
# 10                9             0.0                  P                2012.0
# 11                0             NaN                  F                2013.0
# 12                9             0.0                  E                2012.0
# 13                9             0.0                  E                1999.0
# 14                0             0.0                  F                2013.0
# 15                9             0.0                  P                   NaN
# 16                0             NaN                  P                1998.0
# 17                0             0.0                  F                2013.0
# 18                0             0.0                  E                2012.0
# 19                9             0.0                  P                1988.0
# 20                0             2.0                  F                2012.0
# 21                0             0.0                  F                2014.0
# 22               10             0.0                  E                2006.0
# 23                0             0.0                  E                2006.0
# 24                9             0.0                  E                2009.0
# 25                0             0.0                  P                2013.0
# 26                0             0.0                  E                2013.0
# 27                0             0.0                  E                2013.0
# 28                0             3.0                  E                2013.0
# 29                2             5.0                  P                2012.0
# 30                0             0.0                  E                2012.0
# ...             ...             ...                ...                   ...
# 1288              0             6.0                  P                2005.0
# 1289              0             0.0                  E                2012.0
# 1290              0             NaN                  E                2011.0
# 1291              0             NaN                  P                2004.0
# 1292              0             0.0                  E                2006.0
# 1293              0             0.0                  F                2013.0
# 1294              0             2.0                  E                2009.0
# 1295              0             0.0                  E                2007.0
# 1296              0             0.0                  E                2011.0
# 1297              0             4.0                  P                2012.0
# 1299              0             0.0                  F                2013.0
# 1300              0             0.0                  E                2012.0
# 1301              0             NaN                  F                2013.0
# 1302              0             6.0                  P                2005.0
# 1303              0             0.0                  E                2012.0
# 1304              0             0.0                  E                2006.0
# 1305              0             0.0                  F                2013.0
# 1306              0             0.0                  E                2012.0
# 1307              0             0.0                  P                2012.0
# 1308              0             2.0                  E                2009.0
# 1309              0             0.0                  E                2007.0
# 1310              0             0.0                  E                2011.0
# 1311              0             4.0                  P                2012.0
# 1313              0             0.0                  F                2013.0
# 1314              0             6.0                  P                2005.0
# 1315              0             0.0                  E                2012.0
# 1316              0             0.0                  E                2006.0
# 1317              0             0.0                  F                2013.0
# 1318              0             0.0                  E                2012.0
# 1319              0             NaN                  F                2013.0
#
#       RENDA_PER_CAPITA COD_ESTADO_CIVIL  N_FILHOS SEXO  \
# 0                  NaN                S       NaN    M
# 1                 10.0                S       0.0    F
# 2                 10.0                S       0.0    M
# 3                 10.0                S       0.0    M
# 4                  2.0                S       NaN    M
# 6                  NaN                S       NaN    M
# 7                  NaN                C       NaN    M
# 8                 10.0                S       0.0    M
# 9                 10.0              NaN       0.0    M
# 10                10.0                S       0.0    M
# 11                10.0                S       NaN    F
# 12                10.0                S       NaN    F
# 13                10.0                C       0.0    M
# 14                10.0                S       0.0    M
# 15                10.0                S       0.0    M
# 16                10.0                C       NaN    M
# 17                10.0                S       NaN    M
# 18                10.0                S       NaN    M
# 19                10.0                S       0.0    M
# 20                 0.0                S       0.0    M
# 21                10.0                S       0.0    M
# 22                10.0                C       NaN    M
# 23                10.0                S       NaN    M
# 24                10.0                S       NaN    M
# 25                10.0              NaN       0.0    M
# 26                10.0              NaN       0.0    M
# 27                10.0              NaN       0.0    M
# 28                 2.0                S       NaN    F
# 29                10.0                S       0.0    M
# 30                10.0              NaN       0.0    M
# ...                ...              ...       ...  ...
# 1288              10.0                S       NaN    M
# 1289              10.0              NaN       0.0    M
# 1290               NaN                S       NaN    M
# 1291               NaN                C       NaN    M
# 1292              10.0                S       NaN    M
# 1293              10.0                S       NaN    M
# 1294              10.0                S       0.0    F
# 1295              10.0                S       0.0    M
# 1296              10.0                S       0.0    M
# 1297               2.0                S       NaN    M
# 1299              10.0                S       0.0    M
# 1300              10.0                S       NaN    F
# 1301              10.0                S       NaN    F
# 1302              10.0                S       NaN    M
# 1303              10.0              NaN       0.0    M
# 1304              10.0                S       NaN    M
# 1305              10.0                S       NaN    M
# 1306              10.0                S       NaN    M
# 1307              10.0                S       0.0    M
# 1308              10.0                S       0.0    F
# 1309              10.0                S       0.0    M
# 1310              10.0                S       0.0    M
# 1311               2.0                S       NaN    M
# 1313              10.0                S       0.0    M
# 1314              10.0                S       NaN    M
# 1315              10.0              NaN       0.0    M
# 1316              10.0                S       NaN    M
# 1317              10.0                S       NaN    M
# 1318              10.0                S       NaN    M
# 1319              10.0                S       NaN    F
#
#                 DT_NASCIMENTO               PROFISSAO      ...       \
# 0     1995-03-12 00:00:00.000                     NaN      ...
# 1     1991-04-25 00:00:00.000               ESTUDANTE      ...
# 2     1990-09-03 00:00:00.000                     NaN      ...
# 3     1994-12-12 00:00:00.000        Administrador Ti      ...
# 4     1995-02-05 00:00:00.000    Analista de Sistemas      ...
# 6     1996-06-12 00:00:00.000                     NaN      ...
# 7     1990-07-08 00:00:00.000    Analista de Sistemas      ...
# 8     1995-01-27 00:00:00.000    Analista de Sistemas      ...
# 9     1989-04-24 00:00:00.000                     NaN      ...
# 10    1995-12-05 00:00:00.000                     NaN      ...
# 11    1994-03-24 00:00:00.000                     NaN      ...
# 12    1995-02-13 00:00:00.000                     NaN      ...
# 13    1983-06-08 00:00:00.000                Bombeiro      ...
# 14    1995-09-01 00:00:00.000               Estudante      ...
# 15    1996-12-03 00:00:00.000               Estudante      ...
# 16    1980-06-22 00:00:00.000  Técnico em Informática      ...
# 17    1994-06-01 00:00:00.000                     NaN      ...
# 18    1994-07-11 00:00:00.000                     NaN      ...
# 19    1969-06-17 00:00:00.000                     NaN      ...
# 20    1993-07-17 00:00:00.000               Estudante      ...
# 21    1995-02-20 00:00:00.000               Estudante      ...
# 22    1977-11-16 00:00:00.000                     NaN      ...
# 23    1990-03-29 00:00:00.000                     NaN      ...
# 24    1990-10-30 00:00:00.000                     NaN      ...
# 25    1996-10-06 00:00:00.000                     NaN      ...
# 26    1996-01-23 00:00:00.000                     NaN      ...
# 27    1996-06-24 00:00:00.000                     NaN      ...
# 28    1996-10-14 00:00:00.000               Estudante      ...
# 29    1996-04-25 00:00:00.000               Estudante      ...
# 30    1995-03-23 00:00:00.000                     NaN      ...
# ...                       ...                     ...      ...
# 1288  1987-03-06 00:00:00.000     Analista de Suporte      ...
# 1289  1995-10-07 00:00:00.000                     NaN      ...
# 1290  1990-08-17 00:00:00.000                     NaN      ...
# 1291  1987-10-17 00:00:00.000     Analista de Suporte      ...
# 1292  1990-03-29 00:00:00.000                     NaN      ...
# 1293  1994-06-01 00:00:00.000                     NaN      ...
# 1294  1991-04-25 00:00:00.000               ESTUDANTE      ...
# 1295  1990-09-03 00:00:00.000                     NaN      ...
# 1296  1994-12-12 00:00:00.000        Administrador Ti      ...
# 1297  1995-02-05 00:00:00.000    Analista de Sistemas      ...
# 1299  1994-05-12 00:00:00.000                     NaN      ...
# 1300  1995-08-28 00:00:00.000               Estudante      ...
# 1301  1994-03-24 00:00:00.000                     NaN      ...
# 1302  1987-03-06 00:00:00.000     Analista de Suporte      ...
# 1303  1995-10-07 00:00:00.000                     NaN      ...
# 1304  1990-03-29 00:00:00.000                     NaN      ...
# 1305  1994-06-01 00:00:00.000                     NaN      ...
# 1306  1994-07-11 00:00:00.000                     NaN      ...
# 1307  1995-01-27 00:00:00.000    Analista de Sistemas      ...
# 1308  1991-04-25 00:00:00.000               ESTUDANTE      ...
# 1309  1990-09-03 00:00:00.000                     NaN      ...
# 1310  1994-12-12 00:00:00.000        Administrador Ti      ...
# 1311  1995-02-05 00:00:00.000    Analista de Sistemas      ...
# 1313  1994-05-12 00:00:00.000                     NaN      ...
# 1314  1987-03-06 00:00:00.000     Analista de Suporte      ...
# 1315  1995-10-07 00:00:00.000                     NaN      ...
# 1316  1990-03-29 00:00:00.000                     NaN      ...
# 1317  1994-06-01 00:00:00.000                     NaN      ...
# 1318  1994-07-11 00:00:00.000                     NaN      ...
# 1319  1994-03-24 00:00:00.000                     NaN      ...
#
#      DESC_ESTADO INGLES_FALA  INGLES_COMPREENSAO  INGLES_ESCRITA  \
# 0          Goiás         NaN                 NaN             NaN
# 1          Goiás         NaN                 NaN             NaN
# 2          Goiás         NaN                 NaN             NaN
# 3          Goiás         NaN                 NaN             NaN
# 4          Goiás         1.0                 2.0             1.0
# 6          Goiás         1.0                 2.0             2.0
# 7          Goiás         NaN                 NaN             NaN
# 8          Goiás         NaN                 NaN             NaN
# 9          Goiás         NaN                 NaN             NaN
# 10         Goiás         NaN                 NaN             NaN
# 11         Goiás         NaN                 NaN             NaN
# 12         Goiás         NaN                 NaN             NaN
# 13         Goiás         NaN                 NaN             NaN
# 14         Goiás         NaN                 NaN             NaN
# 15         Goiás         NaN                 NaN             NaN
# 16         Goiás         1.0                 1.0             1.0
# 17         Goiás         NaN                 NaN             NaN
# 18         Goiás         NaN                 NaN             NaN
# 19         Goiás         NaN                 NaN             NaN
# 20         Goiás         NaN                 NaN             NaN
# 21         Goiás         NaN                 NaN             NaN
# 22         Goiás         NaN                 NaN             NaN
# 23         Goiás         NaN                 NaN             NaN
# 24         Goiás         NaN                 NaN             NaN
# 25         Goiás         2.0                 2.0             2.0
# 26         Goiás         NaN                 NaN             NaN
# 27         Goiás         NaN                 NaN             NaN
# 28         Goiás         1.0                 2.0             2.0
# 29         Goiás         1.0                 2.0             2.0
# 30         Goiás         NaN                 NaN             NaN
# ...          ...         ...                 ...             ...
# 1288       Goiás         2.0                 2.0             3.0
# 1289       Goiás         NaN                 NaN             NaN
# 1290       Goiás         NaN                 NaN             NaN
# 1291       Goiás         NaN                 NaN             NaN
# 1292       Goiás         NaN                 NaN             NaN
# 1293       Goiás         NaN                 NaN             NaN
# 1294       Goiás         NaN                 NaN             NaN
# 1295       Goiás         NaN                 NaN             NaN
# 1296       Goiás         NaN                 NaN             NaN
# 1297       Goiás         1.0                 2.0             1.0
# 1299       Goiás         NaN                 NaN             NaN
# 1300       Goiás         NaN                 NaN             NaN
# 1301       Goiás         NaN                 NaN             NaN
# 1302       Goiás         2.0                 2.0             3.0
# 1303       Goiás         NaN                 NaN             NaN
# 1304       Goiás         NaN                 NaN             NaN
# 1305       Goiás         NaN                 NaN             NaN
# 1306       Goiás         NaN                 NaN             NaN
# 1307       Goiás         NaN                 NaN             NaN
# 1308       Goiás         NaN                 NaN             NaN
# 1309       Goiás         NaN                 NaN             NaN
# 1310       Goiás         NaN                 NaN             NaN
# 1311       Goiás         1.0                 2.0             1.0
# 1313       Goiás         NaN                 NaN             NaN
# 1314       Goiás         2.0                 2.0             3.0
# 1315       Goiás         NaN                 NaN             NaN
# 1316       Goiás         NaN                 NaN             NaN
# 1317       Goiás         NaN                 NaN             NaN
# 1318       Goiás         NaN                 NaN             NaN
# 1319       Goiás         NaN                 NaN             NaN
#
#       INGLES_LEITURA       NOTAS N_FALTAS  COD_DISCIPLINA  CARGA_HOR  \
# 0                NaN        0.00     54.0            8028         54
# 1                NaN        7.50     12.0            8028         54
# 2                NaN        7.50      0.0            8028         54
# 3                NaN        7.80      0.0            8028         54
# 4                2.0        8.80      0.0            8028         54
# 6                2.0        9.40      NaN            8028         54
# 7                NaN        7.00      6.0            8028         54
# 8                NaN        6.00      6.0            8028         54
# 9                NaN        0.00     54.0            8028         54
# 10               NaN        0.00     54.0            8028         54
# 11               NaN        8.50      6.0            8028         54
# 12               NaN        0.00     54.0            8028         54
# 13               NaN        8.30      4.0            8028         54
# 14               NaN        7.60      4.0            8028         54
# 15               NaN        0.00     40.0            8028         54
# 16               1.0        6.80      NaN            8028         54
# 17               NaN        8.50      0.0            8028         54
# 18               NaN        6.70      0.0            8028         54
# 19               NaN        3.50     54.0            8028         54
# 20               NaN        0.00     52.0            8028         54
# 21               NaN  07/10/2016      6.0            8028         54
# 22               NaN        6.80      4.0            8028         54
# 23               NaN        7.70      2.0            8028         54
# 24               NaN        6.20      6.0            8028         54
# 25               2.0        6.50      2.0            8028         54
# 26               NaN        6.80      4.0            8028         54
# 27               NaN        7.40      6.0            8028         54
# 28               2.0        8.60      8.0            8028         54
# 29               2.0        8.50      4.0            8028         54
# 30               NaN        7.50      8.0            8028         54
# ...              ...         ...      ...             ...        ...
# 1288             3.0        4.80      0.0           22621         54
# 1289             NaN        6.30      4.0           22621         54
# 1290             NaN        6.90      4.0           22621         54
# 1291             NaN        0.00     54.0           22621         54
# 1292             NaN        6.00     12.0           22621         54
# 1293             NaN        9.30      0.0           22621         54
# 1294             NaN        7.50     16.0           22622         54
# 1295             NaN        4.60     14.0           22622         54
# 1296             NaN        8.70      2.0           22622         54
# 1297             2.0        7.30     10.0           22622         54
# 1299             NaN        8.80      4.0           22622         54
# 1300             NaN        4.40     18.0           22622         54
# 1301             NaN        8.40      6.0           22622         54
# 1302             3.0        7.20      4.0           22622         54
# 1303             NaN        6.30      8.0           22622         54
# 1304             NaN        8.30      4.0           22622         54
# 1305             NaN        8.90      4.0           22622         54
# 1306             NaN  06/10/2016      6.0           22622         54
# 1307             NaN        5.70     14.0           22622         54
# 1308             NaN        8.90      6.0           24711         54
# 1309             NaN  09/10/2016      6.0           24711         54
# 1310             NaN        8.70      0.0           24711         54
# 1311             2.0        9.70      2.0           24711         54
# 1313             NaN        9.50      0.0           24711         54
# 1314             3.0        8.20      6.0           24711         54
# 1315             NaN        8.30      2.0           24711         54
# 1316             NaN        7.30      0.0           24711         54
# 1317             NaN        9.60      0.0           24711         54
# 1318             NaN        6.80      4.0           24711         54
# 1319             NaN        8.90      2.0           24711         54
#
#       ANO_INGRESSO
# 0             2013
# 1             2013
# 2             2013
# 3             2013
# 4             2013
# 6             2016
# 7             2014
# 8             2013
# 9             2013
# 10            2013
# 11            2013
# 12            2013
# 13            2013
# 14            2014
# 15            2014
# 16            2013
# 17            2013
# 18            2013
# 19            2013
# 20            2014
# 21            2014
# 22            2013
# 23            2013
# 24            2013
# 25            2014
# 26            2014
# 27            2014
# 28            2014
# 29            2014
# 30            2014
# ...            ...
# 1288          2013
# 1289          2013
# 1290          2015
# 1291          2014
# 1292          2013
# 1293          2013
# 1294          2013
# 1295          2013
# 1296          2013
# 1297          2013
# 1299          2013
# 1300          2013
# 1301          2013
# 1302          2013
# 1303          2013
# 1304          2013
# 1305          2013
# 1306          2013
# 1307          2013
# 1308          2013
# 1309          2013
# 1310          2013
# 1311          2013
# 1313          2013
# 1314          2013
# 1315          2013
# 1316          2013
# 1317          2013
# 1318          2013
# 1319          2013
#
# [1276 rows x 21 columns]

# %%
# Atribuindo 0 para o nivel de idioma que está como NULL

si.loc[si['INGLES_FALA'].isnull(), 'INGLES_FALA'] = 0
si.loc[si['INGLES_COMPREENSAO'].isnull(), 'INGLES_COMPREENSAO'] = 0
si.loc[si['INGLES_ESCRITA'].isnull(), 'INGLES_ESCRITA'] = 0
si.loc[si['INGLES_LEITURA'].isnull(), 'INGLES_LEITURA'] = 0

si
# Out:
#       SIT_MATRICULA  RENDA_FAMILIAR TIPO_ESCOLA_ORIGEM  ANO_CONCLUSAO_2_GRAU  \
# 0                 9             NaN                  E                2012.0
# 1                 0             2.0                  E                2009.0
# 2                 0             0.0                  E                2007.0
# 3                 0             0.0                  E                2011.0
# 4                 0             4.0                  P                2012.0
# 6                 0             NaN                  E                2013.0
# 7                 0             NaN                  E                2007.0
# 8                 0             0.0                  P                2012.0
# 9                 9             0.0                  E                2007.0
# 10                9             0.0                  P                2012.0
# 11                0             NaN                  F                2013.0
# 12                9             0.0                  E                2012.0
# 13                9             0.0                  E                1999.0
# 14                0             0.0                  F                2013.0
# 15                9             0.0                  P                   NaN
# 16                0             NaN                  P                1998.0
# 17                0             0.0                  F                2013.0
# 18                0             0.0                  E                2012.0
# 19                9             0.0                  P                1988.0
# 20                0             2.0                  F                2012.0
# 21                0             0.0                  F                2014.0
# 22               10             0.0                  E                2006.0
# 23                0             0.0                  E                2006.0
# 24                9             0.0                  E                2009.0
# 25                0             0.0                  P                2013.0
# 26                0             0.0                  E                2013.0
# 27                0             0.0                  E                2013.0
# 28                0             3.0                  E                2013.0
# 29                2             5.0                  P                2012.0
# 30                0             0.0                  E                2012.0
# ...             ...             ...                ...                   ...
# 1288              0             6.0                  P                2005.0
# 1289              0             0.0                  E                2012.0
# 1290              0             NaN                  E                2011.0
# 1291              0             NaN                  P                2004.0
# 1292              0             0.0                  E                2006.0
# 1293              0             0.0                  F                2013.0
# 1294              0             2.0                  E                2009.0
# 1295              0             0.0                  E                2007.0
# 1296              0             0.0                  E                2011.0
# 1297              0             4.0                  P                2012.0
# 1299              0             0.0                  F                2013.0
# 1300              0             0.0                  E                2012.0
# 1301              0             NaN                  F                2013.0
# 1302              0             6.0                  P                2005.0
# 1303              0             0.0                  E                2012.0
# 1304              0             0.0                  E                2006.0
# 1305              0             0.0                  F                2013.0
# 1306              0             0.0                  E                2012.0
# 1307              0             0.0                  P                2012.0
# 1308              0             2.0                  E                2009.0
# 1309              0             0.0                  E                2007.0
# 1310              0             0.0                  E                2011.0
# 1311              0             4.0                  P                2012.0
# 1313              0             0.0                  F                2013.0
# 1314              0             6.0                  P                2005.0
# 1315              0             0.0                  E                2012.0
# 1316              0             0.0                  E                2006.0
# 1317              0             0.0                  F                2013.0
# 1318              0             0.0                  E                2012.0
# 1319              0             NaN                  F                2013.0
#
#       RENDA_PER_CAPITA COD_ESTADO_CIVIL  N_FILHOS SEXO  \
# 0                  NaN                S       NaN    M
# 1                 10.0                S       0.0    F
# 2                 10.0                S       0.0    M
# 3                 10.0                S       0.0    M
# 4                  2.0                S       NaN    M
# 6                  NaN                S       NaN    M
# 7                  NaN                C       NaN    M
# 8                 10.0                S       0.0    M
# 9                 10.0              NaN       0.0    M
# 10                10.0                S       0.0    M
# 11                10.0                S       NaN    F
# 12                10.0                S       NaN    F
# 13                10.0                C       0.0    M
# 14                10.0                S       0.0    M
# 15                10.0                S       0.0    M
# 16                10.0                C       NaN    M
# 17                10.0                S       NaN    M
# 18                10.0                S       NaN    M
# 19                10.0                S       0.0    M
# 20                 0.0                S       0.0    M
# 21                10.0                S       0.0    M
# 22                10.0                C       NaN    M
# 23                10.0                S       NaN    M
# 24                10.0                S       NaN    M
# 25                10.0              NaN       0.0    M
# 26                10.0              NaN       0.0    M
# 27                10.0              NaN       0.0    M
# 28                 2.0                S       NaN    F
# 29                10.0                S       0.0    M
# 30                10.0              NaN       0.0    M
# ...                ...              ...       ...  ...
# 1288              10.0                S       NaN    M
# 1289              10.0              NaN       0.0    M
# 1290               NaN                S       NaN    M
# 1291               NaN                C       NaN    M
# 1292              10.0                S       NaN    M
# 1293              10.0                S       NaN    M
# 1294              10.0                S       0.0    F
# 1295              10.0                S       0.0    M
# 1296              10.0                S       0.0    M
# 1297               2.0                S       NaN    M
# 1299              10.0                S       0.0    M
# 1300              10.0                S       NaN    F
# 1301              10.0                S       NaN    F
# 1302              10.0                S       NaN    M
# 1303              10.0              NaN       0.0    M
# 1304              10.0                S       NaN    M
# 1305              10.0                S       NaN    M
# 1306              10.0                S       NaN    M
# 1307              10.0                S       0.0    M
# 1308              10.0                S       0.0    F
# 1309              10.0                S       0.0    M
# 1310              10.0                S       0.0    M
# 1311               2.0                S       NaN    M
# 1313              10.0                S       0.0    M
# 1314              10.0                S       NaN    M
# 1315              10.0              NaN       0.0    M
# 1316              10.0                S       NaN    M
# 1317              10.0                S       NaN    M
# 1318              10.0                S       NaN    M
# 1319              10.0                S       NaN    F
#
#                 DT_NASCIMENTO               PROFISSAO      ...       \
# 0     1995-03-12 00:00:00.000                     NaN      ...
# 1     1991-04-25 00:00:00.000               ESTUDANTE      ...
# 2     1990-09-03 00:00:00.000                     NaN      ...
# 3     1994-12-12 00:00:00.000        Administrador Ti      ...
# 4     1995-02-05 00:00:00.000    Analista de Sistemas      ...
# 6     1996-06-12 00:00:00.000                     NaN      ...
# 7     1990-07-08 00:00:00.000    Analista de Sistemas      ...
# 8     1995-01-27 00:00:00.000    Analista de Sistemas      ...
# 9     1989-04-24 00:00:00.000                     NaN      ...
# 10    1995-12-05 00:00:00.000                     NaN      ...
# 11    1994-03-24 00:00:00.000                     NaN      ...
# 12    1995-02-13 00:00:00.000                     NaN      ...
# 13    1983-06-08 00:00:00.000                Bombeiro      ...
# 14    1995-09-01 00:00:00.000               Estudante      ...
# 15    1996-12-03 00:00:00.000               Estudante      ...
# 16    1980-06-22 00:00:00.000  Técnico em Informática      ...
# 17    1994-06-01 00:00:00.000                     NaN      ...
# 18    1994-07-11 00:00:00.000                     NaN      ...
# 19    1969-06-17 00:00:00.000                     NaN      ...
# 20    1993-07-17 00:00:00.000               Estudante      ...
# 21    1995-02-20 00:00:00.000               Estudante      ...
# 22    1977-11-16 00:00:00.000                     NaN      ...
# 23    1990-03-29 00:00:00.000                     NaN      ...
# 24    1990-10-30 00:00:00.000                     NaN      ...
# 25    1996-10-06 00:00:00.000                     NaN      ...
# 26    1996-01-23 00:00:00.000                     NaN      ...
# 27    1996-06-24 00:00:00.000                     NaN      ...
# 28    1996-10-14 00:00:00.000               Estudante      ...
# 29    1996-04-25 00:00:00.000               Estudante      ...
# 30    1995-03-23 00:00:00.000                     NaN      ...
# ...                       ...                     ...      ...
# 1288  1987-03-06 00:00:00.000     Analista de Suporte      ...
# 1289  1995-10-07 00:00:00.000                     NaN      ...
# 1290  1990-08-17 00:00:00.000                     NaN      ...
# 1291  1987-10-17 00:00:00.000     Analista de Suporte      ...
# 1292  1990-03-29 00:00:00.000                     NaN      ...
# 1293  1994-06-01 00:00:00.000                     NaN      ...
# 1294  1991-04-25 00:00:00.000               ESTUDANTE      ...
# 1295  1990-09-03 00:00:00.000                     NaN      ...
# 1296  1994-12-12 00:00:00.000        Administrador Ti      ...
# 1297  1995-02-05 00:00:00.000    Analista de Sistemas      ...
# 1299  1994-05-12 00:00:00.000                     NaN      ...
# 1300  1995-08-28 00:00:00.000               Estudante      ...
# 1301  1994-03-24 00:00:00.000                     NaN      ...
# 1302  1987-03-06 00:00:00.000     Analista de Suporte      ...
# 1303  1995-10-07 00:00:00.000                     NaN      ...
# 1304  1990-03-29 00:00:00.000                     NaN      ...
# 1305  1994-06-01 00:00:00.000                     NaN      ...
# 1306  1994-07-11 00:00:00.000                     NaN      ...
# 1307  1995-01-27 00:00:00.000    Analista de Sistemas      ...
# 1308  1991-04-25 00:00:00.000               ESTUDANTE      ...
# 1309  1990-09-03 00:00:00.000                     NaN      ...
# 1310  1994-12-12 00:00:00.000        Administrador Ti      ...
# 1311  1995-02-05 00:00:00.000    Analista de Sistemas      ...
# 1313  1994-05-12 00:00:00.000                     NaN      ...
# 1314  1987-03-06 00:00:00.000     Analista de Suporte      ...
# 1315  1995-10-07 00:00:00.000                     NaN      ...
# 1316  1990-03-29 00:00:00.000                     NaN      ...
# 1317  1994-06-01 00:00:00.000                     NaN      ...
# 1318  1994-07-11 00:00:00.000                     NaN      ...
# 1319  1994-03-24 00:00:00.000                     NaN      ...
#
#      DESC_ESTADO INGLES_FALA  INGLES_COMPREENSAO  INGLES_ESCRITA  \
# 0          Goiás         0.0                 0.0             0.0
# 1          Goiás         0.0                 0.0             0.0
# 2          Goiás         0.0                 0.0             0.0
# 3          Goiás         0.0                 0.0             0.0
# 4          Goiás         1.0                 2.0             1.0
# 6          Goiás         1.0                 2.0             2.0
# 7          Goiás         0.0                 0.0             0.0
# 8          Goiás         0.0                 0.0             0.0
# 9          Goiás         0.0                 0.0             0.0
# 10         Goiás         0.0                 0.0             0.0
# 11         Goiás         0.0                 0.0             0.0
# 12         Goiás         0.0                 0.0             0.0
# 13         Goiás         0.0                 0.0             0.0
# 14         Goiás         0.0                 0.0             0.0
# 15         Goiás         0.0                 0.0             0.0
# 16         Goiás         1.0                 1.0             1.0
# 17         Goiás         0.0                 0.0             0.0
# 18         Goiás         0.0                 0.0             0.0
# 19         Goiás         0.0                 0.0             0.0
# 20         Goiás         0.0                 0.0             0.0
# 21         Goiás         0.0                 0.0             0.0
# 22         Goiás         0.0                 0.0             0.0
# 23         Goiás         0.0                 0.0             0.0
# 24         Goiás         0.0                 0.0             0.0
# 25         Goiás         2.0                 2.0             2.0
# 26         Goiás         0.0                 0.0             0.0
# 27         Goiás         0.0                 0.0             0.0
# 28         Goiás         1.0                 2.0             2.0
# 29         Goiás         1.0                 2.0             2.0
# 30         Goiás         0.0                 0.0             0.0
# ...          ...         ...                 ...             ...
# 1288       Goiás         2.0                 2.0             3.0
# 1289       Goiás         0.0                 0.0             0.0
# 1290       Goiás         0.0                 0.0             0.0
# 1291       Goiás         0.0                 0.0             0.0
# 1292       Goiás         0.0                 0.0             0.0
# 1293       Goiás         0.0                 0.0             0.0
# 1294       Goiás         0.0                 0.0             0.0
# 1295       Goiás         0.0                 0.0             0.0
# 1296       Goiás         0.0                 0.0             0.0
# 1297       Goiás         1.0                 2.0             1.0
# 1299       Goiás         0.0                 0.0             0.0
# 1300       Goiás         0.0                 0.0             0.0
# 1301       Goiás         0.0                 0.0             0.0
# 1302       Goiás         2.0                 2.0             3.0
# 1303       Goiás         0.0                 0.0             0.0
# 1304       Goiás         0.0                 0.0             0.0
# 1305       Goiás         0.0                 0.0             0.0
# 1306       Goiás         0.0                 0.0             0.0
# 1307       Goiás         0.0                 0.0             0.0
# 1308       Goiás         0.0                 0.0             0.0
# 1309       Goiás         0.0                 0.0             0.0
# 1310       Goiás         0.0                 0.0             0.0
# 1311       Goiás         1.0                 2.0             1.0
# 1313       Goiás         0.0                 0.0             0.0
# 1314       Goiás         2.0                 2.0             3.0
# 1315       Goiás         0.0                 0.0             0.0
# 1316       Goiás         0.0                 0.0             0.0
# 1317       Goiás         0.0                 0.0             0.0
# 1318       Goiás         0.0                 0.0             0.0
# 1319       Goiás         0.0                 0.0             0.0
#
#       INGLES_LEITURA       NOTAS N_FALTAS  COD_DISCIPLINA  CARGA_HOR  \
# 0                0.0        0.00     54.0            8028         54
# 1                0.0        7.50     12.0            8028         54
# 2                0.0        7.50      0.0            8028         54
# 3                0.0        7.80      0.0            8028         54
# 4                2.0        8.80      0.0            8028         54
# 6                2.0        9.40      NaN            8028         54
# 7                0.0        7.00      6.0            8028         54
# 8                0.0        6.00      6.0            8028         54
# 9                0.0        0.00     54.0            8028         54
# 10               0.0        0.00     54.0            8028         54
# 11               0.0        8.50      6.0            8028         54
# 12               0.0        0.00     54.0            8028         54
# 13               0.0        8.30      4.0            8028         54
# 14               0.0        7.60      4.0            8028         54
# 15               0.0        0.00     40.0            8028         54
# 16               1.0        6.80      NaN            8028         54
# 17               0.0        8.50      0.0            8028         54
# 18               0.0        6.70      0.0            8028         54
# 19               0.0        3.50     54.0            8028         54
# 20               0.0        0.00     52.0            8028         54
# 21               0.0  07/10/2016      6.0            8028         54
# 22               0.0        6.80      4.0            8028         54
# 23               0.0        7.70      2.0            8028         54
# 24               0.0        6.20      6.0            8028         54
# 25               2.0        6.50      2.0            8028         54
# 26               0.0        6.80      4.0            8028         54
# 27               0.0        7.40      6.0            8028         54
# 28               2.0        8.60      8.0            8028         54
# 29               2.0        8.50      4.0            8028         54
# 30               0.0        7.50      8.0            8028         54
# ...              ...         ...      ...             ...        ...
# 1288             3.0        4.80      0.0           22621         54
# 1289             0.0        6.30      4.0           22621         54
# 1290             0.0        6.90      4.0           22621         54
# 1291             0.0        0.00     54.0           22621         54
# 1292             0.0        6.00     12.0           22621         54
# 1293             0.0        9.30      0.0           22621         54
# 1294             0.0        7.50     16.0           22622         54
# 1295             0.0        4.60     14.0           22622         54
# 1296             0.0        8.70      2.0           22622         54
# 1297             2.0        7.30     10.0           22622         54
# 1299             0.0        8.80      4.0           22622         54
# 1300             0.0        4.40     18.0           22622         54
# 1301             0.0        8.40      6.0           22622         54
# 1302             3.0        7.20      4.0           22622         54
# 1303             0.0        6.30      8.0           22622         54
# 1304             0.0        8.30      4.0           22622         54
# 1305             0.0        8.90      4.0           22622         54
# 1306             0.0  06/10/2016      6.0           22622         54
# 1307             0.0        5.70     14.0           22622         54
# 1308             0.0        8.90      6.0           24711         54
# 1309             0.0  09/10/2016      6.0           24711         54
# 1310             0.0        8.70      0.0           24711         54
# 1311             2.0        9.70      2.0           24711         54
# 1313             0.0        9.50      0.0           24711         54
# 1314             3.0        8.20      6.0           24711         54
# 1315             0.0        8.30      2.0           24711         54
# 1316             0.0        7.30      0.0           24711         54
# 1317             0.0        9.60      0.0           24711         54
# 1318             0.0        6.80      4.0           24711         54
# 1319             0.0        8.90      2.0           24711         54
#
#       ANO_INGRESSO
# 0             2013
# 1             2013
# 2             2013
# 3             2013
# 4             2013
# 6             2016
# 7             2014
# 8             2013
# 9             2013
# 10            2013
# 11            2013
# 12            2013
# 13            2013
# 14            2014
# 15            2014
# 16            2013
# 17            2013
# 18            2013
# 19            2013
# 20            2014
# 21            2014
# 22            2013
# 23            2013
# 24            2013
# 25            2014
# 26            2014
# 27            2014
# 28            2014
# 29            2014
# 30            2014
# ...            ...
# 1288          2013
# 1289          2013
# 1290          2015
# 1291          2014
# 1292          2013
# 1293          2013
# 1294          2013
# 1295          2013
# 1296          2013
# 1297          2013
# 1299          2013
# 1300          2013
# 1301          2013
# 1302          2013
# 1303          2013
# 1304          2013
# 1305          2013
# 1306          2013
# 1307          2013
# 1308          2013
# 1309          2013
# 1310          2013
# 1311          2013
# 1313          2013
# 1314          2013
# 1315          2013
# 1316          2013
# 1317          2013
# 1318          2013
# 1319          2013
#
# [1276 rows x 21 columns]

# %%
# Verificando valores existentes na coluna de situação da matricula

si['SIT_MATRICULA'].unique()
# Out:
# array([ 9,  0, 10,  2], dtype=int64)

# %%
# Normalizando a coluna de situação da matricula, sendo:
# 0 = matriculado
# 1 = evasão (compreende a categoria 2, 9 e 10)

# categoria 0 = Matriculado
# categoria 2 = Trancado
# categoria 9 = Evasão
# categoria 10 = Cancelado

si.loc[si['SIT_MATRICULA']==2,'SIT_MATRICULA'] = 1
si.loc[si['SIT_MATRICULA']==9,'SIT_MATRICULA'] = 1
si.loc[si['SIT_MATRICULA']==10,'SIT_MATRICULA'] = 1

si['SIT_MATRICULA'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#ATRIBUINDO A MÉDIA ARRENDONDADA AOS MISSING VALUES NA RENDA FAMILIAR
# Considerando que 0 = aluno optou por não informar a renda
# No calculo foi desconsiderado quem está com renda familiar = 0

media_ajustada = round(si.loc[si['RENDA_FAMILIAR']!=0,'RENDA_FAMILIAR'].mean())

si.loc[si['RENDA_FAMILIAR'].isnull(),'RENDA_FAMILIAR']=media_ajustada

si['RENDA_FAMILIAR'].unique()
# Out:
# array([ 3.,  2.,  0.,  4.,  5.,  1.,  6.])

# %%
# Verificando valores existentes na coluna de tipo escola origem

si['TIPO_ESCOLA_ORIGEM'].unique()
# Out:
# array(['E', 'P', 'F', nan], dtype=object)

# %%
# Atribuindo uma letra para as tuplas com valor vazio, para identificar que o valor era null
# N é a letra definida para identificar que o valor era null

si.loc[si['TIPO_ESCOLA_ORIGEM'].isnull(),'TIPO_ESCOLA_ORIGEM']='N'

si['TIPO_ESCOLA_ORIGEM'].unique()
# Out:
# array(['E', 'P', 'F', 'N'], dtype=object)

# %%
#DISCRETIZAÇÃO DO TIPO_ESCOLA_ORIGEM
si.loc[si['TIPO_ESCOLA_ORIGEM']=='P','TIPO_ESCOLA_ORIGEM'] = '0'
si.loc[si['TIPO_ESCOLA_ORIGEM']=='E','TIPO_ESCOLA_ORIGEM'] = '1'
si.loc[si['TIPO_ESCOLA_ORIGEM']=='F','TIPO_ESCOLA_ORIGEM'] = '2'
si.loc[si['TIPO_ESCOLA_ORIGEM']=='N','TIPO_ESCOLA_ORIGEM'] = '3'

si['TIPO_ESCOLA_ORIGEM'] = si['TIPO_ESCOLA_ORIGEM'].astype('float64')

si['TIPO_ESCOLA_ORIGEM'].hist()

# %%
#ATRIBUINDO A MÉDIA ARRENDONDADA AOS MISSING VALUES NA RENDA_PER_CAPITA

media = round(si.loc[si['RENDA_PER_CAPITA']!=10,'RENDA_PER_CAPITA'].mean())

si.loc[si['RENDA_PER_CAPITA'].isnull(),'RENDA_PER_CAPITA']=media
#media
si['RENDA_PER_CAPITA'].unique()
# Out:
# array([  2.,  10.,   0.,   1.,   5.])

# %%
#VERIFICANDO VALORES NO ATRIBUTO COD_ESTADO_CIVIL
si['COD_ESTADO_CIVIL'].unique()
# Out:
# array(['S', 'C', nan, 'D'], dtype=object)

# %%
#IMPUTANDO O VALOR DE 'S' (SOLTEIRO) AOS MISSING VALUES EM COD_ESTADO_CIVIL

si.loc[si['COD_ESTADO_CIVIL'].isnull(), 'COD_ESTADO_CIVIL']='S'

si['COD_ESTADO_CIVIL'].unique()
# Out:
# array(['S', 'C', 'D'], dtype=object)

# %%
# Discretização do COD_ESTADO_CIVIL

si.loc[si['COD_ESTADO_CIVIL']=='S','COD_ESTADO_CIVIL']=0
si.loc[si['COD_ESTADO_CIVIL']=='C','COD_ESTADO_CIVIL']=1
si.loc[si['COD_ESTADO_CIVIL']=='D','COD_ESTADO_CIVIL']=2

si['COD_ESTADO_CIVIL'] = si['COD_ESTADO_CIVIL'].astype('float64')

si['COD_ESTADO_CIVIL'].unique()
# Out:
# array([ 0.,  1.,  2.])

# %%
# Atribuindo 0 para os valores null do N_FILHOS

si.loc[si['N_FILHOS'].isnull(),'N_FILHOS']=0

# Se existir algum aluno com mais de um filho, atribuir 1
# Discretizando para:
# 0 = Não tem filho
# 1 = Tem filho

si.loc[si['N_FILHOS']>1,'N_FILHOS']=1

si['N_FILHOS'].unique()
# Out:
# array([ 0.,  1.])

# %%
# Discretizando SEXO
# 0 = Homem (Masculino)
# 1 = Mulher (Feminino)

si.loc[si['SEXO']=='M','SEXO'] = 0
si.loc[si['SEXO']=='F','SEXO'] = 1

si['SEXO'] = si['SEXO'].astype('float64')

#si['SEXO'].unique()
si['SEXO'].hist()

# %%
si['PROFISSAO'].unique()
# Out:
# array([nan, 'ESTUDANTE', 'Administrador Ti', 'Analista de Sistemas',
#        'Bombeiro', 'Estudante', 'T\xc3\xa9cnico em Inform\xc3\xa1tica',
#        'Analista de Suporte',
#        'T\xc3\xa9cnico em Telecomunica\xc3\xa7\xc3\xb5es', 'Call Center',
#        'Auxiliar T\xc3\xa9cnico', 'Pedreiro', 'FUNCIONARIO PUBLICO',
#        'Banc\xc3\xa1rio'], dtype=object)

# %%
# Discretizando PROFISSAO
# 0 = null e estudantes
# 1 = todo o resto

si.loc[si['PROFISSAO'].isnull(),'PROFISSAO']=0
si.loc[si['PROFISSAO']=='ESTUDANTE','PROFISSAO']=0
si.loc[si['PROFISSAO']=='Estudante','PROFISSAO']=0
si.loc[si['PROFISSAO']!=0,'PROFISSAO']=1

si['PROFISSAO'] = si['PROFISSAO'].astype('float64')

si['PROFISSAO'].unique()
# Out:
# array([ 0.,  1.])

# %%
# Verificando valores em NOTAS
si['NOTAS'].unique()
# Out:
# array(['0.00', '7.50', '7.80', '8.80', '9.40', '7.00', '6.00', '8.50',
#        '8.30', '7.60', '6.80', '6.70', '3.50', '07/10/2016', '7.70',
#        '6.20', '6.50', '7.40', '8.60', '8.00', '6.60', '5.50', '6.30',
#        '6.40', '8.20', '5.20', '7.20', '8.70', '10.00', '7.90', '9.50',
#        '5.30', '9.60', '7.30', '9.00', '1.00', '9.20', '3.00', '0.20',
#        '6.90', '06/10/2016', '2.50', '0.80', '1.20', '1.40', '0.90',
#        '4.00', '5.00', '4.80', '2.30', '1.50', '5.40', '1.70', '8.40',
#        '2.40', '9.30', '9.80', '3.80', '3.90', '0.60', '9.70', '2.60',
#        '0.40', '1.30', '2.80', '4.50', '4.60', '2.00', '08/10/2016',
#        '3.20', '1.80', '4.30', '0.50', '0.70', '3.60', '01/10/2016',
#        '5.70', '4.40', '3.30', '1.60', '09/10/2016', '8.90', '9.90',
#        '2.90', '1.90', '04/10/2016', '2.70'], dtype=object)

# %%
#RETIRANDO AS NOTAS QUE CONTÉM UMA DATA (OUTLEIRS)
#SELECIONANDO TODOS OS CAMPOS QUE CONTÉM '/' E ATRIBUINDO A NEGAÇÃO (~) AO DATASET
si = si[~si['NOTAS'].str.contains("/",na=False)]

si['NOTAS'].unique()
# Out:
# array(['0.00', '7.50', '7.80', '8.80', '9.40', '7.00', '6.00', '8.50',
#        '8.30', '7.60', '6.80', '6.70', '3.50', '7.70', '6.20', '6.50',
#        '7.40', '8.60', '8.00', '6.60', '5.50', '6.30', '6.40', '8.20',
#        '5.20', '7.20', '8.70', '10.00', '7.90', '9.50', '5.30', '9.60',
#        '7.30', '9.00', '1.00', '9.20', '3.00', '0.20', '6.90', '2.50',
#        '0.80', '1.20', '1.40', '0.90', '4.00', '5.00', '4.80', '2.30',
#        '1.50', '5.40', '1.70', '8.40', '2.40', '9.30', '9.80', '3.80',
#        '3.90', '0.60', '9.70', '2.60', '0.40', '1.30', '2.80', '4.50',
#        '4.60', '2.00', '3.20', '1.80', '4.30', '0.50', '0.70', '3.60',
#        '5.70', '4.40', '3.30', '1.60', '8.90', '9.90', '2.90', '1.90',
#        '2.70'], dtype=object)

# %%
#AJUSTANDO TIPOS DA NOTA. CONVERTENDO DE OBJECT PARA FLOAT

si['NOTAS'] = pd.to_numeric(si['NOTAS'])

#CRIANDO CAMPO SITUAÇÃO E ATRIBUINDO O VALOR ZERO PARA TODOS

si['APROVADO'] = 0.0

si['NOTAS'].unique()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# array([  0. ,   7.5,   7.8,   8.8,   9.4,   7. ,   6. ,   8.5,   8.3,
#          7.6,   6.8,   6.7,   3.5,   7.7,   6.2,   6.5,   7.4,   8.6,
#          8. ,   6.6,   5.5,   6.3,   6.4,   8.2,   5.2,   7.2,   8.7,
#         10. ,   7.9,   9.5,   5.3,   9.6,   7.3,   9. ,   1. ,   9.2,
#          3. ,   0.2,   6.9,   2.5,   0.8,   1.2,   1.4,   0.9,   4. ,
#          5. ,   4.8,   2.3,   1.5,   5.4,   1.7,   8.4,   2.4,   9.3,
#          9.8,   3.8,   3.9,   0.6,   9.7,   2.6,   0.4,   1.3,   2.8,
#          4.5,   4.6,   2. ,   3.2,   1.8,   4.3,   0.5,   0.7,   3.6,
#          5.7,   4.4,   3.3,   1.6,   8.9,   9.9,   2.9,   1.9,   2.7])

# %%
#ATRIBUINDO APROVADO (1) AO CAMPO SITUAÇÃO COM BASE NA NOTA

si.loc[si['NOTAS']>=6.0,'APROVADO']=1.0

si['APROVADO'].unique()
# Out:
# C:\Anaconda2\lib\site-packages\pandas\core\indexing.py:461: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# array([ 0.,  1.])

# %%
# Verificando valores em N_FALTAS

si['N_FALTAS'].unique()
# Out:
# array([  54.,   12.,    0.,   nan,    6.,    4.,   40.,   52.,    2.,
#           8.,   42.,   50.,   34.,   10.,   36.,  108.,   20.,   80.,
#          90.,   70.,   66.,   16.,   26.,   30.,    1.,    7.,    3.,
#           5.,   48.,   38.,   24.,   32.,   22.,   56.,   28.,   64.,
#          60.,   14.,   58.,   18.,   68.,   15.,   74.,   62.,   19.,
#           9.,   72.])

# %%
# Atribuindo zero para os null em N_FALTAS

si.loc[si['N_FALTAS'].isnull(), 'N_FALTAS']=0

si['N_FALTAS'].unique()
# Out:
# array([  54.,   12.,    0.,    6.,    4.,   40.,   52.,    2.,    8.,
#          42.,   50.,   34.,   10.,   36.,  108.,   20.,   80.,   90.,
#          70.,   66.,   16.,   26.,   30.,    1.,    7.,    3.,    5.,
#          48.,   38.,   24.,   32.,   22.,   56.,   28.,   64.,   60.,
#          14.,   58.,   18.,   68.,   15.,   74.,   62.,   19.,    9.,   72.])

# %%
# Calculando a porcentagem de faltas
# Primeiro transforma a carga horaria em minutos(*60), depois divide por quantos minutos equivale uma aula(/45), 
# Chegando no resultado da quantidade de aulas
si['PORCENTAGEM_FALTAS'] = (si['N_FALTAS'] / (si['CARGA_HOR'] * 60 / 45)) * 100

# Atribuindo como reprovado o aluno que excedeu a porcentagem de faltas

si.loc[si['PORCENTAGEM_FALTAS']>25.0,'APROVADO']=0

# Removendo o atributo criado para auxiliar
si.drop('PORCENTAGEM_FALTAS', axis=1, inplace=True)

#si
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Verificando valores em DESC_ESTADO. Existe apenas alunos com o estado de Goiás
si['DESC_ESTADO'].unique()
# Out:
# array(['Goi\xc3\xa1s'], dtype=object)

# %%
# Removendo estado, pois existe apenas um estado
si.drop('DESC_ESTADO', axis=1, inplace=True)
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
# Verificando valores em DESC_CIDADE
si['DESC_CIDADE'].unique()
# Out:
# array(['Anicuns', 'Aparecida de Goi\xc3\xa2nia', 'Senador Canedo',
#        'Goi\xc3\xa2nia'], dtype=object)

# %%
# Tratando cidades
# C = Capital(Goiânia)
# G = Grande Goiânia(Aparecida de Goiânia, Senador Canedo e Trindade)
# I = Interior de Goiás(Outras cidades de Goiás)

si.loc[si['DESC_CIDADE']=='Goiânia', 'DESC_CIDADE'] = 'C'
si.loc[si['DESC_CIDADE']=='Aparecida de Goiânia', 'DESC_CIDADE'] = 'G'
si.loc[si['DESC_CIDADE']=='Senador Canedo', 'DESC_CIDADE'] = 'G'
si.loc[si['DESC_CIDADE']=='Anicuns', 'DESC_CIDADE'] = 'I'

si['DESC_CIDADE'].unique()
# Out:
# array(['I', 'G', 'C'], dtype=object)

# %%
# Discretizando cidades
# 0 = Capital
# 1 = Grande Goiânia
# 2 = Interior de Goiás

si.loc[si['DESC_CIDADE']=='C', 'DESC_CIDADE'] = 0
si.loc[si['DESC_CIDADE']=='G', 'DESC_CIDADE'] = 1
si.loc[si['DESC_CIDADE']=='I', 'DESC_CIDADE'] = 2

si['DESC_CIDADE'] = si['DESC_CIDADE'].astype('float64')

si['DESC_CIDADE'].hist()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
si.dtypes
# Out:
# SIT_MATRICULA             int64
# RENDA_FAMILIAR          float64
# TIPO_ESCOLA_ORIGEM      float64
# ANO_CONCLUSAO_2_GRAU    float64
# RENDA_PER_CAPITA        float64
# COD_ESTADO_CIVIL        float64
# N_FILHOS                float64
# SEXO                    float64
# DT_NASCIMENTO            object
# PROFISSAO               float64
# DESC_CIDADE             float64
# INGLES_FALA             float64
# INGLES_COMPREENSAO      float64
# INGLES_ESCRITA          float64
# INGLES_LEITURA          float64
# NOTAS                   float64
# N_FALTAS                float64
# COD_DISCIPLINA            int64
# CARGA_HOR                 int64
# ANO_INGRESSO              int64
# APROVADO                float64
# dtype: object

# %%
si['IDADE_INGRESSO'] = si['ANO_INGRESSO'].astype('float64') - si['DT_NASCIMENTO'].str[:4].astype('float64')

si['IDADE_INGRESSO'].unique()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# array([ 18.,  22.,  23.,  19.,  20.,  24.,  30.,  33.,  44.,  21.,  36.,
#         39.,  27.,  45.,  25.,  26.,  17.,  58.,  29.,  35.,  38.])

# %%
#VERIFICANDO ASSOCIAÇÃO DO ANO_INGRESSO COM O ANO_CONCLUSAO_2_GRAU
grau2 = si[['IDADE_INGRESSO','ANO_CONCLUSAO_2_GRAU','APROVADO']]

sb.pairplot(grau2.dropna(), hue='APROVADO')

# %%
#EXCLUINDO OUTLIER DA SÉRIE HISTÓRICA E REGERANDO PLOT

grau2_clean = grau2.loc[si['IDADE_INGRESSO']<50]
#sb.pairplot(grau2_clean.dropna(), hue='APROVADO')

sb.lmplot(x="IDADE_INGRESSO", 
          y="ANO_CONCLUSAO_2_GRAU", 
          col="APROVADO", 
          hue="APROVADO", 
          data=grau2_clean, 
          col_wrap=2, ci=None, 
          palette="muted", 
          size=4, scatter_kws={"s": 50, "alpha": 1})

# %%
# Regressão Linear

import numpy as np

from sklearn import linear_model

grau3 = si[['IDADE_INGRESSO','ANO_CONCLUSAO_2_GRAU']]
grau3 = grau3.loc[si['IDADE_INGRESSO']<40] 

#CRANDO BASE DE TREINO SEM ANO_CONCLUSAO_2_GRAU NULOS 
treino_pd = grau3.loc[~grau3['ANO_CONCLUSAO_2_GRAU'].isnull()]

#CRANDO BASE DE REGRESSÃO COM ANO_CONCLUSAO_2_GRAU NULOS (PANDAS pd)
prdict_pd = grau3.loc[grau3['ANO_CONCLUSAO_2_GRAU'].isnull()]


treino_np = treino_pd.as_matrix()
prdict_np = prdict_pd.as_matrix()

prdict_np
# Out:
# array([[ 18.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 18.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 18.,  nan],
#        [ 18.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 21.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 21.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan],
#        [ 18.,  nan],
#        [ 21.,  nan],
#        [ 18.,  nan]])

# %%
treino_np
# Out:
# array([[   18.,  2012.],
#        [   22.,  2009.],
#        [   23.,  2007.],
#        ...,
#        [   19.,  2013.],
#        [   19.,  2012.],
#        [   19.,  2013.]])

# %%
#CRIANDO UM OBJETO DE REGRESSÃO LINEAR DO SCIKIT-LEARN
regr = linear_model.LinearRegression()

#SEPARANDO O X E O Y PARA A REGRESSÃO DO CONJUNTO DE TREINO
idade_ingresso_treino = treino_np[:, np.newaxis, 0]
ano_conclusao_treino = treino_np[:, np.newaxis, 1]

#TREINANDO COM O CONJUNTO DE TREINO X E Y PARA REGRESSÃO
regr.fit(idade_ingresso_treino, ano_conclusao_treino)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#IDADES_INGRESSO QUE NÃO TEM ANO_CONCLUSAO_2_GRAU PARA A REGRESSAO
#SELECIONANDO A IDADE_INGRESSO DE TESTE PARA REALIZAR PREDIÇÃO DO ANO_CONCLUSAO_2_GRAU

idade_ingresso_predict = prdict_np[:, np.newaxis, 0]
idade_ingresso_predict
# Out:
# array([[ 18.],
#        [ 18.],
#        [ 21.],
#        [ 18.],
#        [ 18.],
#        [ 18.],
#        [ 21.],
#        [ 18.],
#        [ 21.],
#        [ 21.],
#        [ 18.],
#        [ 18.],
#        [ 21.],
#        [ 18.],
#        [ 18.],
#        [ 18.],
#        [ 18.],
#        [ 21.],
#        [ 18.],
#        [ 21.],
#        [ 18.],
#        [ 18.],
#        [ 21.],
#        [ 18.],
#        [ 21.],
#        [ 21.],
#        [ 21.],
#        [ 18.],
#        [ 18.],
#        [ 21.],
#        [ 18.],
#        [ 21.],
#        [ 21.],
#        [ 21.],
#        [ 18.],
#        [ 18.],
#        [ 21.],
#        [ 18.],
#        [ 21.],
#        [ 18.],
#        [ 21.],
#        [ 21.],
#        [ 18.],
#        [ 18.],
#        [ 21.],
#        [ 18.]])

# %%
#REALIZANDO A REGRESSÃO

ano_predict = regr.predict(idade_ingresso_predict)

ano_predict
# Out:
# array([[ 2013.03687612],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2013.03687612],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2013.03687612],
#        [ 2013.03687612],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2010.66378213],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2010.66378213],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2010.66378213],
#        [ 2013.03687612],
#        [ 2013.03687612],
#        [ 2010.66378213],
#        [ 2013.03687612]])

# %%
#JUNTANDO A REGRESSÃO DO ANO_CONCLUSAO_2_GRAU COM A IDADE_INGRESSO

prdict_np[:, np.newaxis, 1] = ano_predict

prdict_np
# Out:
# array([[   18.        ,  2013.03687612],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   18.        ,  2013.03687612],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   18.        ,  2013.03687612],
#        [   18.        ,  2013.03687612],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   21.        ,  2010.66378213],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   21.        ,  2010.66378213],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612],
#        [   18.        ,  2013.03687612],
#        [   21.        ,  2010.66378213],
#        [   18.        ,  2013.03687612]])

# %%
# Salvando a predição

si.loc[si['ANO_CONCLUSAO_2_GRAU'].isnull(), 'ANO_CONCLUSAO_2_GRAU'] = prdict_np[:, np.newaxis, 1]

si['ANO_CONCLUSAO_2_GRAU'].unique()
# Out:
# array([ 2012.        ,  2009.        ,  2007.        ,  2011.        ,
#         2013.        ,  1999.        ,  2013.03687612,  1998.        ,
#         1988.        ,  2006.        ,  1997.        ,  2010.66378213,
#         2008.        ,  2004.        ,  1992.        ,  2014.        ,
#         1982.        ,  2010.        ,  2005.        ,  1996.        ])

# %%
#retirando virgulas do ano
si['ANO_CONCLUSAO_2_GRAU'] = si['ANO_CONCLUSAO_2_GRAU'].astype('int64')
si['ANO_CONCLUSAO_2_GRAU'].unique()
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# array([2012, 2009, 2007, 2011, 2013, 1999, 1998, 1988, 2006, 1997, 2010,
#        2008, 2004, 1992, 2014, 1982, 2005, 1996], dtype=int64)

# %%
si.dtypes
# Out:
# SIT_MATRICULA             int64
# RENDA_FAMILIAR          float64
# TIPO_ESCOLA_ORIGEM      float64
# ANO_CONCLUSAO_2_GRAU      int64
# RENDA_PER_CAPITA        float64
# COD_ESTADO_CIVIL        float64
# N_FILHOS                float64
# SEXO                    float64
# DT_NASCIMENTO            object
# PROFISSAO               float64
# DESC_CIDADE             float64
# INGLES_FALA             float64
# INGLES_COMPREENSAO      float64
# INGLES_ESCRITA          float64
# INGLES_LEITURA          float64
# NOTAS                   float64
# N_FALTAS                float64
# COD_DISCIPLINA            int64
# CARGA_HOR                 int64
# ANO_INGRESSO              int64
# APROVADO                float64
# IDADE_INGRESSO          float64
# dtype: object

# %%
# Excluindo colunas: DT_NASCIMENTO, CARGA_HOR

si.drop('DT_NASCIMENTO',axis=1, inplace=True)
si.drop('CARGA_HOR',axis=1, inplace=True)

si.dtypes
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# SIT_MATRICULA             int64
# RENDA_FAMILIAR          float64
# TIPO_ESCOLA_ORIGEM      float64
# ANO_CONCLUSAO_2_GRAU      int64
# RENDA_PER_CAPITA        float64
# COD_ESTADO_CIVIL        float64
# N_FILHOS                float64
# SEXO                    float64
# PROFISSAO               float64
# DESC_CIDADE             float64
# INGLES_FALA             float64
# INGLES_COMPREENSAO      float64
# INGLES_ESCRITA          float64
# INGLES_LEITURA          float64
# NOTAS                   float64
# N_FALTAS                float64
# COD_DISCIPLINA            int64
# ANO_INGRESSO              int64
# APROVADO                float64
# IDADE_INGRESSO          float64
# dtype: object

# %%
# Salvando

si.to_csv('si_clean.csv', index=False)

# %%
si.describe()
# Out:
#        SIT_MATRICULA  RENDA_FAMILIAR  TIPO_ESCOLA_ORIGEM  \
# count    1222.000000     1222.000000         1222.000000
# mean        0.148936        1.051555            0.922259
# std         0.356171        1.627908            0.784585
# min         0.000000        0.000000            0.000000
# 25%         0.000000        0.000000            0.000000
# 50%         0.000000        0.000000            1.000000
# 75%         0.000000        2.000000            1.000000
# max         1.000000        6.000000            3.000000
#
#        ANO_CONCLUSAO_2_GRAU  RENDA_PER_CAPITA  COD_ESTADO_CIVIL     N_FILHOS  \
# count           1222.000000       1222.000000       1222.000000  1222.000000
# mean            2010.208674          8.461538          0.089198     0.015548
# std                4.726057          3.220239          0.330385     0.123770
# min             1982.000000          0.000000          0.000000     0.000000
# 25%             2009.000000         10.000000          0.000000     0.000000
# 50%             2012.000000         10.000000          0.000000     0.000000
# 75%             2013.000000         10.000000          0.000000     0.000000
# max             2014.000000         10.000000          2.000000     1.000000
#
#               SEXO    PROFISSAO  DESC_CIDADE  INGLES_FALA  INGLES_COMPREENSAO  \
# count  1222.000000  1222.000000  1222.000000  1222.000000         1222.000000
# mean      0.163666     0.226678     0.256956     0.338789            0.452537
# std       0.370124     0.418854     0.448234     0.666098            0.833741
# min       0.000000     0.000000     0.000000     0.000000            0.000000
# 25%       0.000000     0.000000     0.000000     0.000000            0.000000
# 50%       0.000000     0.000000     0.000000     0.000000            0.000000
# 75%       0.000000     0.000000     1.000000     0.000000            0.000000
# max       1.000000     1.000000     2.000000     3.000000            3.000000
#
#        INGLES_ESCRITA  INGLES_LEITURA        NOTAS     N_FALTAS  \
# count     1222.000000     1222.000000  1222.000000  1222.000000
# mean         0.436170        0.503273     6.718494     8.115385
# std          0.824741        0.930636     2.957801    14.637323
# min          0.000000        0.000000     0.000000     0.000000
# 25%          0.000000        0.000000     6.200000     0.000000
# 50%          0.000000        0.000000     7.600000     4.000000
# 75%          0.000000        0.000000     8.700000     8.000000
# max          3.000000        3.000000    10.000000   108.000000
#
#        COD_DISCIPLINA  ANO_INGRESSO     APROVADO  IDADE_INGRESSO
# count     1222.000000   1222.000000  1222.000000     1222.000000
# mean     19175.308511   2013.860884     0.798691       21.616203
# std       4578.785338      0.859666     0.401143        5.676294
# min       8028.000000   2013.000000     0.000000       17.000000
# 25%      19403.000000   2013.000000     1.000000       18.000000
# 50%      20179.000000   2014.000000     1.000000       19.000000
# 75%      22581.000000   2014.000000     1.000000       23.000000
# max      24711.000000   2016.000000     1.000000       58.000000
